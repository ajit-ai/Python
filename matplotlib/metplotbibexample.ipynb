# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample telemetry data
data = pd.DataFrame({'time': [1, 2, 3, 4], 'altitude': [1000, 2000, 2500, 3000]})
data.plot(x='time', y='altitude', title='Rocket Altitude')
plt.show()

# Export as .ipynb or .py for GitHub sharing
